# %% [markdown]
# To make this script faster, the search for children is done on a file that contains only the videos of the keyword of the parent. For that, the data file with all the videos was split using the following command:
#
# awk -F\, '{print>$1}' classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
import csv
import os
import pandas as pd
from shutil import copy #file
from os import listdir

csv.field_size_limit(300000) # Some records are too large and require a larger field_size_limit
# Out:
# 131072

# %%
def addSeed(csv_in, csv_out, keywords, biases, depth):
    print('Createing seed file:', csv_out)
    count=0
    print('Keywords:', keywords)
    print('Biases:', biases)
    print('Depth:', depth)
    
    with open ("model/plotting/" + csv_out, 'w') as write_obj:
        csv_writer = csv.writer(write_obj)

        with open("model/" + csv_in, 'r') as read_obj:
            csv_reader = csv.reader(read_obj)
            row=next(csv_reader)
            row.append('parentVideoRow0')
            csv_writer.writerow(row)

            if keywords==[]:
                print('No keywords')

                for row in csv_reader:
                    if count % 150000 == 0:
                        print("Read: " + str(count))
                    count += 1
 
                    if (row[17] in biases or (row[17]=="" and row[14] in biases)) and int(row[3])==depth:
                    #if row[16] in biases and int(row[3])==depth and row[2]=='andrew cuomo':
                        #row.append(0)
                        csv_writer.writerow(row)
            elif biases==[]:
                print('No biasess')
                for row in csv_reader:
                    if count % 150000 == 0:
                        print("Read: " + str(count))
                    count += 1

                    if row[0] in keywords and int(row[3])==depth:
                        #row.append(0)
                        csv_writer.writerow(row)
            else:
                print('Keywords and biasess')
                for row in csv_reader:
                    if count % 150000 == 0:
                        print("Read: " + str(count))
                    count += 1

                    if (row[17] in biases or (row[17]=="" and row[14] in biases)) and row[0] in keywords and int(row[3])==depth:
                        #row.append(0)
                        csv_writer.writerow(row)

# %%
def addChildren(csv_in, csv_seed, csv_out, depth):
    count=0
    next_depth=depth + 1
    print('Depth:', depth, csv_seed)

    df_seed=pd.read_csv("model/plotting/" + csv_seed)
    videos=set(df_seed[df_seed['current_depth']==depth]['video'].values)
    keywords=set(df_seed[df_seed['current_depth']==depth]['keyword'].values)
    traces=set(df_seed[df_seed['current_depth']==depth]['trace'].values)

    print(len(videos))

    with open ("model/plotting/" + csv_out, 'a') as write_obj:
        csv_writer = csv.writer(write_obj)

        with open("model/" + csv_in, 'r') as read_obj:
            csv_reader = csv.reader(read_obj)
            next(csv_reader, None)

            for row in csv_reader:
                if count % 150000 == 0:
                    print("Read: " + str(count))
                count += 1
                if row[0] in keywords:
                    if int(row[3])==next_depth:
                        if int(row[13]) in traces:
                            keyword=row[0].replace(" ", "")
                            csv_lookup_seed=keyword + "_" + str(depth) + "_" + csv_seed
                            with open("model/plotting/" + csv_lookup_seed, 'r') as seed_read_obj:
                                csv_seed_reader = csv.reader(seed_read_obj)
                                next(csv_seed_reader, None)
                                for seed_row in csv_seed_reader:
                                    #if int(seed_row[3])==depth:
                                    if int(seed_row[12])==int(row[13]) and seed_row[1]==row[2]:
                                        csv_writer.writerow(row)

# %%
def addChildren(csv_seed, depth):
    count=0
    next_depth=depth + 1
    csv_temp_seed="temp_seed.csv"
    print('Depth:', depth, csv_seed)

    copy("model/plotting/" + csv_seed, "model/plotting/" + csv_temp_seed)

    with open("model/plotting/" + csv_temp_seed, 'r') as seed_read_obj:
        csv_seed_reader = csv.reader(seed_read_obj)
        next(csv_seed_reader, None)

        for seed_row in csv_seed_reader:
            if int(seed_row[3])==depth:
                children=0
                keyword=seed_row[0]
                seed_trace=int(seed_row[12])
                seed_video=seed_row[1]

                with open("model/" + keyword, 'r') as read_obj:
                    csv_reader = csv.reader(read_obj)
                    for row in csv_reader:
                        if int(row[3])==next_depth:
                            if int(row[13])==seed_trace:
                                if row[2]==seed_video:

                                    with open ("model/plotting/" + csv_seed, 'a') as write_obj:
                                        csv_writer = csv.writer(write_obj)
                                        csv_writer.writerow(row)
                                    if children==4:
                                        #print("Found all chilren")
                                        break
                                    else:
                                        children+=1

# %%
def add1Child(csv_in, csv_seed, csv_out, depth):
    count=0
    next_depth=depth + 1
    print('Depth:', depth, csv_seed)

    df_seed=pd.read_csv("model/plotting/" + csv_seed)
    videos=set(df_seed[df_seed['current_depth']==depth]['video'].values)
    keywords=set(df_seed[df_seed['current_depth']==depth]['keyword'].values)
    traces=set(df_seed[df_seed['current_depth']==depth]['trace'].values)

    print(len(videos))

    with open ("model/plotting/" + csv_out, 'a') as write_obj:
        csv_writer = csv.writer(write_obj)

        with open("model/" + csv_in, 'r') as read_obj:
            csv_reader = csv.reader(read_obj)
            next(csv_reader, None)

            for row in csv_reader:
                if count % 150000 == 0:
                    print("Read: " + str(count))
                count += 1
                if int(row[3])==next_depth:
                    if int(row[13]) in traces:
                        if row[0] in keywords:
                            keyword=row[0].replace(" ", "")
                            csv_lookup_seed=keyword + "_" + str(depth) + "_" + csv_seed
                            with open("model/plotting/" + csv_lookup_seed, 'r') as seed_read_obj:
                                csv_seed_reader = csv.reader(seed_read_obj)
                                next(csv_seed_reader, None)
                                for seed_row in csv_seed_reader:
                                    #if int(seed_row[3])==depth:
                                    if int(seed_row[12])==int(row[13]):
                                        csv_writer.writerow(row)

# %%
def splitSeedFile(csv_in, depth):
    count=0
    last_id=0
    print("Splitting depth ", depth)
    with open("model/plotting/" + csv_in, 'r') as read_obj:
        csv_reader = csv.reader(read_obj)
        #next(csv_reader, None)

        for row in csv_reader:
            #print("Splitting: " + str(count))
            count += 1
            if row[3]=='current_depth':
                header_row=row
                continue
            if int(row[3])==depth:
                keyword=row[0].replace(" ", "")
                csv_out=keyword + "_" + str(depth) + "_" + csv_in

                if not os.path.exists('model/plotting/' + csv_out):
                    with open ("model/plotting/" + csv_out, 'w') as write_obj:
                        csv_writer = csv.writer(write_obj)
                        #csv_writer.writerow(('X', 'video', 'keyword', 'current_depth', 'fetch_time', 'parent_video', 'positive', 'negative', 'sentiment', 'sentiment_ratio', 'lgpp', 'nrc_el', 'topic', 'Flesch', 'ARI', 'Flesch.Kincaid', 'Bias', 'sentiment_ratio_plot', 'flech_level', 'ARI_level', 'flesch_kincaid_level', 'parentVideoRow0'))                    
                        csv_writer.writerow(header_row)                    

                if last_id==0:
                    with open ("model/plotting/" + csv_out, 'a') as write_obj:
                        csv_writer = csv.writer(write_obj)
                        #if keyword=='TedCruz':
                            #print('if', row[0], row[3], count)
                        csv_writer.writerow(row)
                        previous_row=row
                        last_id=int(row[12])
                elif row[12]!=last_id:
                    #print('Second', row[0], csv_out)
                    with open ("model/plotting/" + csv_out, 'a') as write_obj:
                        #if keyword=='TedCruz':
                            #print('else', row[0], row[3], count)
                        csv_writer = csv.writer(write_obj)
                        csv_writer.writerow(row)
                        last_id=int(row[12])

# %%
def addSeedlgpp(csv_in, csv_out, lgpps, depth):
    print('Createing seed file:', csv_out)
    count=0
    print('lgpp:', lgpps)
    print('Depth:', depth)
    
    with open ("model/plotting/" + csv_out, 'w') as write_obj:
        csv_writer = csv.writer(write_obj)

        with open("model/" + csv_in, 'r') as read_obj:
            csv_reader = csv.reader(read_obj)
            row=next(csv_reader)
            row.append('parentVideoRow0')
            csv_writer.writerow(row)

            if lgpps==[]:
                print('No keywords')

            else:
                print('With lgpp')
                for row in csv_reader:
                    if count % 150000 == 0:
                        print("Read: " + str(count))
                    count += 1

                    if row[63] in lgpps and int(row[3])==depth:
                        csv_writer.writerow(row)

# %%
def addSeednrc_el(csv_in, csv_out, nrc_els, depth):
    print('Createing seed file:', csv_out)
    count=0
    print('nrc_el:', nrc_els)
    print('Depth:', depth)
    
    with open ("model/plotting/" + csv_out, 'w') as write_obj:
        csv_writer = csv.writer(write_obj)

        with open("model/" + csv_in, 'r') as read_obj:
            csv_reader = csv.reader(read_obj)
            row=next(csv_reader)
            row.append('parentVideoRow0')
            csv_writer.writerow(row)

            if nrc_els==[]:
                print('No nrc_els')

            else:
                print('With nrc_els')
                for row in csv_reader:
                    if count % 150000 == 0:
                        print("Read: " + str(count))
                    count += 1

                    if row[74] in nrc_els and int(row[3])==depth:
                        csv_writer.writerow(row)

# %%
def addSeedlm(csv_in, csv_out, lms, depth):
    print('Createing seed file:', csv_out)
    count=0
    print('lms:', lms)
    print('Depth:', depth)
    
    with open ("model/plotting/" + csv_out, 'w') as write_obj:
        csv_writer = csv.writer(write_obj)

        with open("model/" + csv_in, 'r') as read_obj:
            csv_reader = csv.reader(read_obj)
            row=next(csv_reader)
            row.append('parentVideoRow0')
            csv_writer.writerow(row)

            if lms==[]:
                print('No lms')
            else:
                print('With lms')
                for row in csv_reader:
                    if count % 150000 == 0:
                        print("Read: " + str(count))
                    count += 1

                    if row[53] in lms and int(row[3])==depth:
                        csv_writer.writerow(row)

# %%
def addSeedhuliu(csv_in, csv_out, hulius, depth):
    print('Createing seed file:', csv_out)
    count=0
    print('hulius:', hulius)
    print('Depth:', depth)
    
    with open ("Subtitles/" + csv_out, 'w') as write_obj:
        csv_writer = csv.writer(write_obj)

        with open("Subtitles/" + csv_in, 'r') as read_obj:
            csv_reader = csv.reader(read_obj)
            row=next(csv_reader)
            row.append('parentVideoRow0')
            csv_writer.writerow(row)

            if hulius==[]:
                print('No hulius')

            else:
                print('With hulius')
                for row in csv_reader:
                    if count % 150000 == 0:
                        print("Read: " + str(count))
                    count += 1

                    if row[42] in hulius and int(row[3])==depth:
                        csv_writer.writerow(row)

# %%
def addSeedgeninqposneg(csv_in, csv_out, geninqposnegs, depth):
    print('Createing seed file:', csv_out)
    count=0
    print('geninqposnegs:', geninqposnegs)
    print('Depth:', depth)
    
    with open ("Subtitles/" + csv_out, 'w') as write_obj:
        csv_writer = csv.writer(write_obj)

        with open("Subtitles/" + csv_in, 'r') as read_obj:
            csv_reader = csv.reader(read_obj)
            row=next(csv_reader)
            row.append('parentVideoRow0')
            csv_writer.writerow(row)

            if geninqposnegs==[]:
                print('No geninqposnegs')

            else:
                print('With geninqposnegs')
                for row in csv_reader:
                    if count % 150000 == 0:
                        print("Read: " + str(count))
                    count += 1

                    if row[42] in geninqposnegs and int(row[3])==depth:
                        csv_writer.writerow(row)

# %%
def addSeedafinn(csv_in, csv_out, afinns, depth):
    print('Createing seed file:', csv_out)
    count=0
    print('afinns:', afiafinnsnns)
    print('Depth:', depth)
    
    with open ("Subtitles/" + csv_out, 'w') as write_obj:
        csv_writer = csv.writer(write_obj)

        with open("Subtitles/" + csv_in, 'r') as read_obj:
            csv_reader = csv.reader(read_obj)
            row=next(csv_reader)
            row.append('parentVideoRow0')
            csv_writer.writerow(row)

            if afinns==[]:
                print('No afinns')

            else:
                print('With afinns')
                for row in csv_reader:
                    if count % 150000 == 0:
                        print("Read: " + str(count))
                    count += 1

                    if row[32] in afinns and int(row[3])==depth:
                        csv_writer.writerow(row)

# %%
def addSeedlsd(csv_in, csv_out, lsds, depth):
    print('Createing seed file:', csv_out)
    count=0
    print('lsds:', lsds)
    print('Depth:', depth)
    
    with open ("Subtitles/" + csv_out, 'w') as write_obj:
        csv_writer = csv.writer(write_obj)

        with open("Subtitles/" + csv_in, 'r') as read_obj:
            csv_reader = csv.reader(read_obj)
            row=next(csv_reader)
            row.append('parentVideoRow0')
            csv_writer.writerow(row)

            if lsds==[]:
                print('No lsds')

            else:
                print('With lsds')
                for row in csv_reader:
                    if count % 150000 == 0:
                        print("Read: " + str(count))
                    count += 1

                    if row[27] in lsds and int(row[3])==depth:
                        csv_writer.writerow(row)

# %%
csv_in = "classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv"

# %%
keyword_prefix = 'Center'
keywords=[]
biases=['C']
depth=0

csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeed(csv_in, csv_out, keywords, biases, depth)
#copy("model/plotting/" + csv_out0, "model/plotting/" + csv_out)

addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: Center_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Keywords: []
# Biases: ['C']
# Depth: 0
# No keywords
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 Center_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 Center_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 Center_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 Center_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 Center_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
keyword_prefix = 'Right'
keywords=[]
biases=['R']
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeed(csv_in, csv_out, keywords, biases, depth)
#copy("model/plotting/" + csv_out0, "model/plotting/" + csv_out)

addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Keywords: []
# Biases: ['R']
# Depth: 0
# No keywords
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
keyword_prefix = 'Center-Right'
keywords=[]
biases=['CR', 'RC']
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeed(csv_in, csv_out, keywords, biases, depth)
#copy("model/plotting/" + csv_out0, "model/plotting/" + csv_out)

addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: Center-Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Keywords: []
# Biases: ['CR', 'RC']
# Depth: 0
# No keywords
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 Center-Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 Center-Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 Center-Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 Center-Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 Center-Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
keyword_prefix = 'Right-Center-Right'
keywords=[]
biases=['R', 'CR', 'RC']
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeed(csv_in, csv_out, keywords, biases, depth)
#copy("model/plotting/" + csv_out0, "model/plotting/" + csv_out)

addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: Right-Center-Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Keywords: []
# Biases: ['R', 'CR', 'RC']
# Depth: 0
# No keywords
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 Right-Center-Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 Right-Center-Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 Right-Center-Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 Right-Center-Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 Right-Center-Right_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
keyword_prefix = 'Center-Left'
keywords=[]
biases=['CL', 'LC']
depth=0

#csv_in = "videos_for_clustering2021-06-25_13_14_45.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeed(csv_in, csv_out, keywords, biases, depth)
#copy("model/plotting/" + csv_out0, "model/plotting/" + csv_out)

addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: Center-Left_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Keywords: []
# Biases: ['CL', 'LC']
# Depth: 0
# No keywords
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 Center-Left_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 Center-Left_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 Center-Left_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 Center-Left_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 Center-Left_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
keyword_prefix = 'Left'
keywords=[]
biases=['L']
depth=0

#csv_in = "videos_for_clustering2021-06-25_13_14_45.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeed(csv_in, csv_out, keywords, biases, depth)
#copy("model/plotting/" + csv_out0, "model/plotting/" + csv_out)

addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: Left_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Keywords: []
# Biases: ['L']
# Depth: 0
# No keywords
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 Left_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 Left_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 Left_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 Left_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 Left_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
keyword_prefix = "lgpp_culture"
keywords=["culture"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeedlgpp(csv_in, csv_out0, keywords, depth)

addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: lgpp_culture_0_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# lgpp: ['culture']
# Depth: 0
# With lgpp
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 lgpp_culture_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 lgpp_culture_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 lgpp_culture_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 lgpp_culture_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 lgpp_culture_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
keyword_prefix = "lgpp_economy"
keywords=["economy"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeedlgpp(csv_in, csv_out0, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: lgpp_economy_0_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# lgpp: ['economy']
# Depth: 0
# With lgpp
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 lgpp_economy_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 lgpp_economy_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 lgpp_economy_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 lgpp_economy_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 lgpp_economy_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
keyword_prefix = "lgpp_groups"
keywords=["groups"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeedlgpp(csv_in, csv_out0, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: lgpp_groups_0_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# lgpp: ['groups']
# Depth: 0
# With lgpp
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 lgpp_groups_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 lgpp_groups_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 lgpp_groups_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 lgpp_groups_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 lgpp_groups_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
keyword_prefix = "lgpp_institutions"
keywords=["institutions"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeedlgpp(csv_in, csv_out0, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: lgpp_institutions_0_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# lgpp: ['institutions']
# Depth: 0
# With lgpp
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 lgpp_institutions_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 lgpp_institutions_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 lgpp_institutions_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 lgpp_institutions_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 lgpp_institutions_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
keyword_prefix = "lgpp_law_and_order"
keywords=["law_and_order"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeedlgpp(csv_in, csv_out, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: lgpp_law_and_order_0_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# lgpp: ['law_and_order']
# Depth: 0
# With lgpp
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 lgpp_law_and_order_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-65-c248f7647290> in <module>
#       8
#       9 addSeedlgpp(csv_in, csv_out0, keywords, depth)
# ---> 10 addChildren(csv_out, 0)
#      11 addChildren(csv_out, 1)
#      12 addChildren(csv_out, 2)
#
# <ipython-input-52-3451c8c80b7e> in addChildren(csv_seed, depth)
#       4     print('Depth:', depth, csv_seed)
#       5
# ----> 6     copy("model/plotting/" + csv_seed, "model/plotting/" + csv_temp_seed)
#       7
#       8     with open("model/plotting/" + csv_temp_seed, 'r') as seed_read_obj:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/shutil.py in copy(src, dst, follow_symlinks)
#     413     if os.path.isdir(dst):
#     414         dst = os.path.join(dst, os.path.basename(src))
# --> 415     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     416     copymode(src, dst, follow_symlinks=follow_symlinks)
#     417     return dst
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/shutil.py in copyfile(src, dst, follow_symlinks)
#     259         os.symlink(os.readlink(src), dst)
#     260     else:
# --> 261         with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     262             # macOS
#     263             if _HAS_FCOPYFILE:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model/plotting/lgpp_law_and_order_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv'

# %%
keyword_prefix = "lgpp_rural"
keywords=["rural"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeedlgpp(csv_in, csv_out, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)

# %%
keyword_prefix = "lgpp_urban"
keywords=["urban"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeedlgpp(csv_in, csv_out, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)

# %%
keyword_prefix = "lgpp_values"
keywords=["values"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeedlgpp(csv_in, csv_out, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)

# %%
keyword_prefix = "nrc_elanger"
keywords=["anger"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeednrc_el(csv_in, csv_out0, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)

# %%
keyword_prefix = "nrc_el_anticipation"
keywords=["anticipation"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeednrc_el(csv_in, csv_out0, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)

# %%
keyword_prefix = "nrc_el_disgust"
keywords=["disgust"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeednrc_el(csv_in, csv_out0, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)

# %%
keyword_prefix = "nrc_el_fear"
keywords=["fear"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeednrc_el(csv_in, csv_out0, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)

# %%
keyword_prefix = "nrc_el_joy"
keywords=["joy"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeednrc_el(csv_in, csv_out0, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)

# %%
keyword_prefix = "nrc_el_negative"
keywords=["negative"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeednrc_el(csv_in, csv_out0, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)

# %%
keyword_prefix = "nrc_el_positive"
keywords=["positive"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeednrc_el(csv_in, csv_out0, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)

# %%
keyword_prefix = "nrc_el_sadness"
keywords=["sadness"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeednrc_el(csv_in, csv_out0, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)

# %%
keyword_prefix = "nrc_el_surprise"
keywords=["surprise"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeednrc_el(csv_in, csv_out0, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)

# %%
keyword_prefix = "nrc_el_trust"
keywords=["trust"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeednrc_el(csv_in, csv_out0, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)

# %%
keyword_prefix = "lm_negative"
keywords=["negative"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeedlm(csv_in, csv_out, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: lm_negative_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# lms: ['negative']
# Depth: 0
# With lms
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 lm_negative_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 lm_negative_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 lm_negative_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 lm_negative_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 lm_negative_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
keyword_prefix = "lm_positive"
keywords=["positive"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeedlm(csv_in, csv_out, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: lm_positive_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# lms: ['positive']
# Depth: 0
# With lms
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 lm_positive_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 lm_positive_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 lm_positive_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 lm_positive_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 lm_positive_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
keyword_prefix = "lm_uncertainty"
keywords=["uncertainty"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeedlm(csv_in, csv_out, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: lm_uncertainty_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# lms: ['uncertainty']
# Depth: 0
# With lms
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 lm_uncertainty_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 lm_uncertainty_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 lm_uncertainty_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 lm_uncertainty_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 lm_uncertainty_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
keyword_prefix = "lm_litigious"
keywords=["litigious"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeedlm(csv_in, csv_out, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: lm_litigious_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# lms: ['litigious']
# Depth: 0
# With lms
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 lm_litigious_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 lm_litigious_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 lm_litigious_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 lm_litigious_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 lm_litigious_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
keyword_prefix = "lm_constraining"
keywords=["constraining"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeedlm(csv_in, csv_out, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: lm_constraining_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# lms: ['constraining']
# Depth: 0
# With lms
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 lm_constraining_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 lm_constraining_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 lm_constraining_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 lm_constraining_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 lm_constraining_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
keyword_prefix = "lm_superfluous"
keywords=["superfluous"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeedlm(csv_in, csv_out, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: lm_superfluous_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# lms: ['superfluous']
# Depth: 0
# With lms
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 lm_superfluous_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 lm_superfluous_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 lm_superfluous_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 lm_superfluous_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 lm_superfluous_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv

# %%
keyword_prefix = "lm_interesting"
keywords=["interesting"]
depth=0

#csv_in = "videos_for_clustering2021-06-12_21_01_20.csv"
csv_out0 = keyword_prefix + "_0_" + csv_in
csv_out = keyword_prefix + "_" + csv_in

addSeedlm(csv_in, csv_out, keywords, depth)
addChildren(csv_out, 0)
addChildren(csv_out, 1)
addChildren(csv_out, 2)
addChildren(csv_out, 3)
addChildren(csv_out, 4)
# Out:
# Createing seed file: lm_interesting_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# lms: ['interesting']
# Depth: 0
# With lms
# Read: 0
# Read: 150000
# Read: 300000
# Read: 450000
# Depth: 0 lm_interesting_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 1 lm_interesting_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 2 lm_interesting_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 3 lm_interesting_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
# Depth: 4 lm_interesting_classified_videos_proportional_Dataset5_top152022-01-28_18_36_39.csv
